# %%
# 2x Transformation sistemi test
from database import source_db, analytics_db
from modules.fixtures_2x import Fixtures2x

# Transformer oluştur
transformer = Fixtures2x()

# Tam süreci çalıştır
transformer.run_full_transformation("fixtures_2x")
# Out:
# 🚀 FIXTURES 2X TRANSFORMATION BAŞLIYOR
# ...
# 📊 Kaynak veriler çekiliyor...
# c:\Users\monscer\OneDrive\Desktop\Spradar1\database\source_connection.py:54: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(sql, conn, params=params)
#    ✅ 29,044 kayıt çekildi
# 🔄 2x Transformation uygulanıyor...
#    ✅ 2x Transformation tamamlandı: 29,044 → 58,088 kayıt
# 💾 Analytics DB'ye kaydediliyor (fixtures_2x)...
# 🔨 fixtures_2x tablosu oluşturuluyor...
# ⚡ 58,088 kayıt fixtures_2x tablosuna yükleniyor...
# 🔨 fixtures_2x tablosu oluşturuluyor...
# ⚡ 58,088 kayıt fixtures_2x tablosuna yükleniyor...
# ✅ fixtures_2x tablosu oluşturuldu (58,088 kayıt)
#    ✅ 58,088 kayıt başarıyla kaydedildi
#
# 🎉 TRANSFORMATION TAMAMLANDI!
#    📊 Kaynak: 29,044 maç
#    🔄 Sonuç: 58,088 kayıt
#    💾 Tablo: fixtures_2x
# ...
